# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/hotel_list.csv")
vacation_df.head()
# Out:
#    City_ID              City Country  Max Temp Current Description    Lat  \
# 0        0    ribeira grande      PT     73.63           clear sky  38.52
# 1        1  praia da vitoria      PT     77.00          few clouds  38.73
# 2        2            atuona      PF     78.46           clear sky  -9.80
# 3        3           arteaga      MX     73.96          light rain  18.47
# 4        4            japura      BR     72.91       broken clouds  -0.32
#
#       Lng           Hotel Name
# 0  -28.70  Quinta da Meia Eira
# 1  -27.07       Hotel Branco I
# 2 -139.03          Villa Enata
# 3 -102.42                  NaN
# 4  102.35     Rumah mbah Jamah

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl><dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Description:</dt><dd>{Current Description}</dd>
</dl>
"""
clean_hotel_df = vacation_df.dropna()
# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
vacation_list = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]
locations_df = pd.DataFrame(locations)

# %%
# 4a. Add a marker layer for each city to the map.

fig = gmaps.figure(center=(18.0, 15.0), zoom_level=2.3)

marker_layer = gmaps.marker_layer(locations_df, info_box_content=info_box_template)

fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

import random

# finding which countries have the most cities from our randomly selected subset
vacation_df.groupby('Country').count().reset_index().sort_values(('City_ID'), ascending=False)

country_filtered_df = vacation_df.loc[(vacation_df['Country']=='BR')]
vacation_start = filtered_df.iloc[[0]]


#temp = vacation_start['Max Temp']
#max_temp = temp + 9
#min_temp = temp - 9

vacation_end = vacation_start

temp_filtered_df = country_filtered_df[(country_filtered_df['Max Temp'] <= max_temp) & 
                                       (country_filtered_df['Max Temp'] >= min_temp) &
                                       (country_filtered_df['City'] != filtered_df.iloc[0]['City'])]

indices = random.sample(range(0,len(temp_filtered_df)),3)

vacation_stop1 = temp_filtered_df.iloc[[indices[0]]]
vacation_stop2 = temp_filtered_df.iloc[[indices[1]]]
vacation_stop3 = temp_filtered_df.iloc[[indices[2]]]
temp_filtered_df
# Out:
#      City_ID                      City Country  Max Temp Current Description  \
# 4          4                    japura      BR     72.91       broken clouds
# 52       135        humberto de campos      BR     77.67           clear sky
# 61       152               salinopolis      BR     80.31     overcast clouds
# 64       160                vila velha      BR     72.00    scattered clouds
# 77       187                   pitimbu      BR     73.40       broken clouds
# 89       217                  cabedelo      BR     73.40       broken clouds
# 91       224                    touros      BR     75.20          few clouds
# 96       235                carutapera      BR     76.33       broken clouds
# 99       239                   camocim      BR     78.26          few clouds
# 114      271                 boa vista      BR     80.60         shower rain
# 129      310                 caravelas      BR     68.67     overcast clouds
# 140      333                frei paulo      BR     78.80    scattered clouds
# 156      379            augusto correa      BR     76.57       moderate rain
# 208      525                 piacabucu      BR     73.29          few clouds
# 219      544  rio verde de mato grosso      BR     78.55           clear sky
# 227      563                  cururupu      BR     75.78       broken clouds
# 248      609                    maceio      BR     73.40          few clouds
# 254      620                   aquiraz      BR     78.80    scattered clouds
# 263      646                    gurupa      BR     76.96          light rain
# 271      659                     irece      BR     73.42          few clouds
# 278      677       sao jose de ribamar      BR     77.00       broken clouds
# 279      678  sao jose da coroa grande      BR     74.05     overcast clouds
#
#        Lat     Lng                                     Hotel Name
# 4    -0.32  102.35                               Rumah mbah Jamah
# 52   -2.60  -43.46                              Pousada do Cabeça
# 61   -0.61  -47.36                              Hotel Salinópolis
# 64  -20.33  -40.29                           Hotel Vitória Palace
# 77   -7.47  -34.81                               Reserva do Abiaí
# 89   -6.98  -34.83                              Lua Mansa Pousada
# 91   -5.20  -35.46                                INN NEW HORIZON
# 96   -1.20  -46.02                                         Lidera
# 99   -2.90  -40.84                             Hotel Ilha do Amor
# 114   2.82  -60.67                             Aipana Plaza Hotel
# 129 -17.71  -39.25                         Pousada dos Navegantes
# 140 -10.55  -37.53  Restaurante e Pousada Nossa Senhora De Fátima
# 156  -1.02  -46.63                                 Fazenda Bacuri
# 208 -10.41  -36.43                                 Piaçabuçu News
# 219 -18.92  -54.84                                 Hotel Valência
# 227  -1.83  -44.87                             Pousada Través'cia
# 248  -9.67  -35.74                  Mercure Maceio Pajucara Hotel
# 254  -3.90  -38.39                               Hotel Laguna Blu
# 263  -1.41  -51.64                                Residencial DWD
# 271 -11.30  -41.86                                RADAR INN HOTEL
# 278  -2.56  -44.05                                   Decida Praia
# 279  -8.90  -35.15                               Crôa Mares Hotel

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
import numpy as np

specific_country = temp_filtered_df[['Lat','Lng']]
coordinates = specific_country.to_numpy()
start = tuple(coordinates[1])
end = tuple(coordinates[1])
stop1 = tuple(coordinates[2])
stop2 = tuple(coordinates[3])
stop3 = tuple(coordinates[4])
start, stop1, stop2, stop3, end
# Out:
# ((-2.6, -43.46),
#  (-0.61, -47.36),
#  (-20.33, -40.29),
#  (-7.47, -34.81),
#  (-2.6, -43.46))

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
import gmaps
import gmaps.datasets
from config import g_key
gmaps.configure(api_key = g_key)


base_url = 'http://maps.googleapis.com/maps/api/directions/json?'

fig = gmaps.figure()
wholeTrip = gmaps.directions_layer(start, end, waypoints=[stop3, stop2, stop1], show_markers=True, travel_mode='DRIVING', stroke_weight=3.0, stroke_opacity=1.0)
fig.add_layer(wholeTrip)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3, vacation_end],keys=('vacation_start', 'vacation_stop1', 'vacation_stop2', 'vacation_stop3', 'vacation_end'),ignore_index=True)
itinerary_df
# Out:
#    City_ID                 City Country  Max Temp Current Description   Lat  \
# 0        4              itarema      BR     77.59           clear sky -2.92
# 1      224               touros      BR     75.20          few clouds -5.20
# 2      677  sao jose de ribamar      BR     77.00       broken clouds -2.56
# 3      271            boa vista      BR     80.60         shower rain  2.82
# 4        4              itarema      BR     77.59           clear sky -2.92
#
#      Lng          Hotel Name
# 0 -39.92         Windvillage
# 1 -35.46     INN NEW HORIZON
# 2 -44.05        Decida Praia
# 3 -60.67  Aipana Plaza Hotel
# 4 -39.92         Windvillage

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Description:</dt><dd>{Current Description}</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
city_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = pd.DataFrame({'Lat': (start[0],stop1[0],stop2[0],stop3[0],end[0]),
                          'Lng': (start[1],stop1[1],stop2[1],stop3[1],end[1])})
locations
# Out:
#      Lat    Lng
# 0  -2.60 -43.46
# 1  -0.61 -47.36
# 2 -20.33 -40.29
# 3  -7.47 -34.81
# 4  -2.60 -43.46

# %%
# 11a. Add a marker layer for each city to the map. 

fig = gmaps.figure(center=(-10.60, -43.46), zoom_level=4)

marker_layer = gmaps.marker_layer(locations, info_box_content=city_info)

fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
