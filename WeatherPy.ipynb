# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
coordinates
# Out:
# [(30.366398738775388, 88.64312481234714),
#  (-56.221167004965146, -95.72839703143688),
#  (10.395570646353846, -65.25135761058009),
#  (43.298445600013196, -129.26406407418503),
#  (63.99728499857727, 142.97413932509488),
#  (-60.90039533241287, -55.896283778731274),
#  (32.64638737202634, -58.59550455848165),
#  (4.168502761797839, -22.10023781515096),
#  (-17.525940303740313, 36.384871154617485),
#  (-44.055956573964984, -119.7763398410847),
#  (53.37001246676718, 112.36167334065476),
#  (47.916735825228244, 105.23625984292659),
#  (1.4502187907015838, 71.19207567885499),
#  (31.812500067583514, -14.781450643390684),
#  (43.723789984008505, 42.9075868360099),
#  (-80.77416302235376, -15.213980969305538),
#  (-51.60694781454326, -16.623745946979255),
#  (-38.28490692438468, 57.41527892620368),
#  (28.0252401426894, 124.11058972056378),
#  (-61.95591022587372, -100.58464725579576),
#  (32.476437582228684, 62.6242632132155),
#  (-31.391392808449623, -84.98231411167062),
# ...

# %%
from citipy import citipy

# %%
for coordinate in coordinates:
    city_name = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    country_name = citipy.nearest_city(coordinate[0],coordinate[1]).country_code.upper()
    print(f"City name: {city_name}, Country: {country_name}")
# Out:
# City name: lasa, Country: CN
# City name: punta arenas, Country: CL
# City name: barcelona, Country: VE
# City name: north bend, Country: US
# City name: ust-nera, Country: RU
# City name: ushuaia, Country: AR
# City name: saint george, Country: BM
# City name: bubaque, Country: GW
# City name: quelimane, Country: MZ
# City name: rikitea, Country: PF
# City name: sosnovo-ozerskoye, Country: RU
# City name: erdenet, Country: MN
# City name: thinadhoo, Country: MV
# City name: porto santo, Country: PT
# City name: kamennomostskoye, Country: RU
# City name: cape town, Country: ZA
# City name: jamestown, Country: SH
# City name: taolanaro, Country: MG
# City name: shenjiamen, Country: CN
# City name: punta arenas, Country: CL
# City name: farah, Country: AF
# City name: lebu, Country: CL
# City name: arraial do cabo, Country: BR
# City name: naze, Country: JP
# City name: mahebourg, Country: MU
# City name: mataura, Country: PF
# City name: mandan, Country: US
# ...

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# lasa cn
# punta arenas cl
# barcelona ve
# north bend us
# ust-nera ru
# ushuaia ar
# saint george bm
# bubaque gw
# quelimane mz
# rikitea pf
# sosnovo-ozerskoye ru
# erdenet mn
# thinadhoo mv
# porto santo pt
# kamennomostskoye ru
# cape town za
# jamestown sh
# taolanaro mg
# shenjiamen cn
# punta arenas cl
# farah af
# lebu cl
# arraial do cabo br
# naze jp
# mahebourg mu
# mataura pf
# mandan us
# pevek ru
# merauke id
# jamestown sh
# plymouth us
# miandrivazo mg
# vaitupu wf
# bredasdorp za
# mataura pf
# broken hill au
# mar del plata ar
# krasnoarmeysk kz
# port elizabeth za
# ushuaia ar
# rikitea pf
# barrow us
# bluff nz
# ushuaia ar
# hammerfest no
# gloversville us
# illoqqortoormiut gl
# albany au
# taolanaro mg
# mataura pf
# sentyabrskiy ru
# luderitz na
# sao joao da barra br
# coquimbo cl
# bluff nz
# hambantota lk
# lagoa pt
# coihaique cl
# hamilton bm
# khatanga ru
# belushya guba ru
# vaini to
# fairbanks us
# bluff nz
# puerto ayora ec
# rikitea pf
# ...

# %%
# iterating through tuples of coordinates and appending corresponding nearest city to list
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 617

# %%
from config import weather_api_key
from datetime import datetime
import requests

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

'''
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
'''

# enumerate allows us to obtain both city name and its index without using 2 for loops
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city, remove black spaces in url to search for exact city names
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lasa
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | barcelona
# Processing Record 4 of Set 1 | north bend
# Processing Record 5 of Set 1 | ust-nera
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | saint george
# Processing Record 8 of Set 1 | bubaque
# Processing Record 9 of Set 1 | quelimane
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | sosnovo-ozerskoye
# Processing Record 12 of Set 1 | erdenet
# Processing Record 13 of Set 1 | thinadhoo
# Processing Record 14 of Set 1 | porto santo
# Processing Record 15 of Set 1 | kamennomostskoye
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | shenjiamen
# Processing Record 20 of Set 1 | farah
# ...

# %%
# find how many cities are in dataset
len(city_data)
# Out:
# 563

# %%
import pandas as pd
city_data[2]
# Out:
# {'City': 'Barcelona',
#  'Lat': 41.39,
#  'Lng': 2.16,
#  'Max Temp': 81,
#  'Humidity': 83,
#  'Cloudiness': 0,
#  'Wind Speed': 4.7,
#  'Country': 'ES',
#  'Date': '2020-08-19 23:25:34'}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          Lasa  46.62   10.70     59.00        87          40        1.12
# 1  Punta Arenas -53.15  -70.92     46.40        75          85       34.45
# 2     Barcelona  41.39    2.16     81.00        83           0        4.70
# 3    North Bend  43.41 -124.22     71.01        82           1        9.17
# 4      Ust-Nera  64.57  143.20     45.10        76          99        7.74
# 5       Ushuaia -54.80  -68.30     39.20        93          90       24.16
# 6  Saint George  37.10 -113.58    109.99        10           1        9.17
# 7       Bubaque  11.28  -15.83     81.34        86          93        8.88
# 8     Quelimane -17.88   36.89     75.20        83          52        4.70
# 9       Rikitea -23.12 -134.97     70.41        86         100       22.15
#
#   Country                 Date
# 0      IT  2020-08-19 23:27:29
# 1      CL  2020-08-19 23:27:29
# 2      ES  2020-08-19 23:25:34
# ...

# %%
newColOrder = ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']
city_data_df = city_data_df[newColOrder]
city_data_df
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0            Lasa      IT  2020-08-19 23:27:29  46.62   10.70     59.00
# 1    Punta Arenas      CL  2020-08-19 23:27:29 -53.15  -70.92     46.40
# 2       Barcelona      ES  2020-08-19 23:25:34  41.39    2.16     81.00
# 3      North Bend      US  2020-08-19 23:27:29  43.41 -124.22     71.01
# 4        Ust-Nera      RU  2020-08-19 23:27:29  64.57  143.20     45.10
# ..            ...     ...                  ...    ...     ...       ...
# 558    Twin Falls      US  2020-08-19 23:29:43  42.56 -114.46     96.80
# 559       Te Anau      NZ  2020-08-19 23:29:43 -45.42  167.72     46.89
# 560        Kijang      KR  2020-08-19 23:29:44  35.24  129.21     82.40
# 561      Lalmohan      BD  2020-08-19 23:29:44  22.34   90.74     82.09
# 562    Los Alamos      US  2020-08-19 23:29:44  35.89 -106.31     90.00
#
#      Humidity  Cloudiness  Wind Speed
# 0          87          40        1.12
# ...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '08/19/20'

# %%
plt.scatter(lats, max_temps,
           edgecolor = 'black', linewidths = 1, marker = 'o',
           alpha = 0.8)

plt.title(f"City Latitude Vs. Max Temperature" + today)
plt.ylabel(f"Max Temperature (F)")
plt.xlabel(f"Latitude")
plt.grid(True)

plt.savefig('weather_Data/Fig1.png')

plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
